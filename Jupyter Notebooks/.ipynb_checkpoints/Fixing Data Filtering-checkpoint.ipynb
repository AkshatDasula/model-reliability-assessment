# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Loading Datasets

# %%
baseline = pd.read_csv("./Heart Disease Prediction/baseline.csv")

# %%
ground_truths = pd.read_csv("./Heart Disease Prediction/Ground Truths/07th Feb 2024.csv")

# %%
production_run = pd.read_csv("./Heart Disease Prediction/Production Runs/07th Feb 2024.csv")

# %%
baseline.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   48   F           ASY        138          214          0     Normal    108
# 3   54   M           NAP        150          195          0     Normal    122
# 4   45   F           ATA        130          237          0     Normal    170
#
#   ExerciseAngina  Oldpeak ST_Slope  target
# 0              N      0.0       Up       0
# 1              N      1.0     Flat       1
# 2              Y      1.5     Flat       1
# 3              N      0.0       Up       0
# 4              N      0.0       Up       0

# %%
ground_truths.head()
# Out:
#    Unnamed: 0  Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0         668   63   F           ATA        140          195          0
# 1          30   53   M           NAP        145          518          0
# 2         377   65   M           ASY        160            0          1
# 3         535   56   M           ASY        130            0          0
# 4         807   54   M           ATA        108          309          0
#
#   RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  target
# 0     Normal    179              N      0.0       Up       0
# 1     Normal    130              N      0.0     Flat       1
# 2         ST    122              N      1.2     Flat       1
# 3        LVH    122              Y      1.0     Flat       1
# 4     Normal    156              N      0.0       Up       0

# %%
production_run.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   63   F           ATA      140.0        195.0        0.0     Normal  179.0
# 1   53   M           NAP      145.0        518.0        0.0     Normal  130.0
# 2   65   M           ASY      160.0          0.0        1.0         ST  122.0
# 3   56   M           ASY      130.0          0.0        0.0        LVH  122.0
# 4   54   M           ATA      108.0        309.0        0.0     Normal  156.0
#
#   ExerciseAngina  Oldpeak ST_Slope  target  probs
# 0              N      0.0       Up       0    1.0
# 1              N      0.0     Flat       1    0.6
# 2              N      1.2     Flat       1    1.0
# 3              Y      1.0     Flat       1    1.0
# 4              N      0.0       Up       0    1.0

# %%
ground_truths.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# ### Checking the filtering code

# %%
baseline[baseline['Oldpeak'].isin(range(2,4))]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 6     58   M           ATA        136          164          0         ST
# 13    36   M           ATA        120          267          0     Normal
# 17    53   M           ASY        124          260          0         ST
# 19    54   M           ASY        125          224          0     Normal
# 30    47   F           ASY        120          205          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 403   64   M           ASY        145          212          0        LVH
# 406   53   M           ASY        123          282          0     Normal
# 467   60   M           NAP        140          185          0        LVH
# 489   57   M           ASY        110          335          0     Normal
# 490   55   F           ASY        128          205          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  target
# 6       99              Y      2.0     Flat       1
# 13     160              N      3.0     Flat       1
# 17     112              Y      3.0     Flat       0
# 19     122              N      2.0     Flat       1
# 30      98              Y      2.0     Flat       1
# ..     ...            ...      ...      ...     ...
# 403    132              N      2.0     Flat       1
# 406     95              Y      2.0     Flat       1
# 467    155              N      3.0     Flat       1
# 489    143              Y      3.0     Flat       1
# 490    130              Y      2.0     Flat       1
#
# [61 rows x 12 columns]

# %%
from utils import determine_dtype_ft

# %%
cat_ft, num_ft = determine_dtype_ft(baseline)

# %%
cat_ft, num_ft
# Out:
# (['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope'],
#  ['Age',
#   'RestingBP',
#   'Cholesterol',
#   'FastingBS',
#   'MaxHR',
#   'Oldpeak',
#   'target'])

# %%
num_conds, cat_conds = dict(), dict()

for i in list(baseline.columns)[:3]:
    cond = input(f"Enter condition for {i}")
    
    if i in cat_ft:
        cat_conds[i] = cond
    if i in num_ft:
        num_conds[i] = cond
    if cond == "No":
        continue
# Out:
# Enter condition for Age30-50
# Enter condition for SexM
# Enter condition for ChestPainTypeASY

# %%
num_conds, cat_conds
# Out:
# ({'Age': '30-50'}, {'Sex': 'M', 'ChestPainType': 'ASY'})

# %%
num_conds['Age'].split('-')
# Out:
# ['30', '50']

# %%
'30-'.split('-')
# Out:
# ['30', '']

# %%
'M' in list(baseline['Sex'].unique())
# Out:
# True

# %%
not all([list(baseline['Sex'].unique()), True])
# Out:
# False

# %%
baseline['Age'].min()
# Out:
# 29

# %%
num_conds['Age'] = '40'

# %%
cat_conds['Sex'] = ['M']
cat_conds['ChestPainType'] = ['ASY', 'ATA']

# %%
cat_conds
# Out:
# {'Sex': ['M'], 'ChestPainType': ['ASY', 'ATA']}

# %%
def new_filter_data(df, num_conds, cat_conds):
    
    """
    df: DataFrame to filter
    num_conds: Numerical Conditions that we get from webpage
    cat_conds: Categorical Conditions that we get from webpage
    
    Returns the filtered DataFrame
    """
    
    for i in list(cat_conds.keys()):
        unique_cats = list(df[i].unique())
        if not all([j in unique_cats for j in cat_conds[i]]):
            print("Wrong Category Entered, Can't Filter")
            return None
        else:
            df = df[df[i].isin(cat_conds[i])]
    
    for i in list(num_conds.keys()):
        if '-' in num_conds[i]:
            splits = num_conds[i].split('-')
            limits = [df[i].min() if splits[0] == '' else float(splits[0]), df[i].max() if splits[1] == '' else float(splits[1])]
            
            df = df[(df[i]>=limits[0]) & (df[i]<=limits[1])]
        else:
            try:
                df = df[df[i] == float(num_conds[i])]
            except:
                print("Invalid format to filter Numerical Columns")
                return None
    
    return df

# %%
filtered_df = new_filter_data(baseline, num_conds, cat_conds)

# %%
baseline[baseline['Sex'].isin(cat_conds['Sex'])]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 3     54   M           NAP        150          195          0     Normal
# 6     58   M           ATA        136          164          0         ST
# 7     49   M           ASY        140          234          0     Normal
# 10    38   M           ASY        110          196          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 494   56   M           ATA        120          240          0     Normal
# 495   67   M           NAP        152          212          0        LVH
# 497   63   M           ASY        140          187          0        LVH
# 498   68   M           ASY        144          193          1     Normal
# 499   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  target
# 0      172              N      0.0       Up       0
# 3      122              N      0.0       Up       0
# 6       99              Y      2.0     Flat       1
# 7      140              Y      1.0     Flat       1
# 10     166              N      0.0     Flat       1
# ..     ...            ...      ...      ...     ...
# 494    169              N      0.0     Down       0
# 495    150              N      0.8     Flat       1
# 497    144              Y      4.0       Up       1
# 498    141              N      3.4     Flat       1
# 499    173              N      0.0       Up       0
#
# [381 rows x 12 columns]

# %%
unique_cats = list(baseline['Sex'].unique())

# %%
[j in unique_cats for j in cat_conds['Sex']]
# Out:
# [True]

# %%
all([j in unique_cats for j in cat_conds['Sex']])
# Out:
# True

# %%
cat_conds['Sex']
# Out:
# ['M']

# %%
filtered_df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 50    40   M           ASY        120          466          1     Normal
# 233   40   M           ASY        125            0          1     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  target
# 0      172              N      0.0       Up       0
# 50     152              Y      1.0     Flat       1
# 233    165              N      0.0     Flat       1

# %%
filtered_df['Age'].max(), filtered_df['Age'].min()
# Out:
# (40, 40)

# %%
filtered_df['Sex'].unique(), filtered_df['ChestPainType'].unique()
# Out:
# (array(['M'], dtype=object), array(['ATA', 'ASY'], dtype=object))

# %%
baseline.max()
# Out:
# Age                77
# Sex                 M
# ChestPainType      TA
# RestingBP         200
# Cholesterol       603
# FastingBS           1
# RestingECG         ST
# MaxHR             192
# ExerciseAngina      Y
# Oldpeak           6.2
# ST_Slope           Up
# target              1
# dtype: object

# %%
from utils import classification_metrics

# %%
filtered_gt = new_filter_data(ground_truths, num_conds, cat_conds)

# %%
filtered_pr = new_filter_data(production_run, num_conds, cat_conds)

# %%
sample = filtered_pr['target']

# %%
sample[31] = 1

# %%
# Out:
# 31     1
# 98     1
# 176    1
# Name: target, dtype: int64

# %%
filtered_gt['target'], filtered_pr['target']
# Out:
# (31     1
#  98     1
#  176    1
#  Name: target, dtype: int64,
#  31     0
#  98     1
#  176    1
#  Name: target, dtype: int64)

# %%
results = classification_metrics(filtered_gt['target'], filtered_pr['target'])
# Out:
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# D:\Anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-7b6c87c6bc76> in <module>
# ----> 1 results = classification_metrics(filtered_gt['target'], filtered_pr['target'])
#
# ~\Desktop\Root-Cause-Analysis-for-Model-Drift\Jupyter Notebooks\utils.py in classification_metrics(true_labels, predicted_labels, labels)
#     225         metrics['Recall'] = np.round(recall_score(true_labels, predicted_labels)*100, decimals=2)
#     226         metrics['F1'] = np.round(f1_score(true_labels, predicted_labels)*100, decimals=2)
# --> 227         metrics['ROC_AUC'] = np.round(roc_auc_score(true_labels, predicted_labels)*100, decimals=2)
#     228         true_negative, false_positive, false_negative, true_positive = confusion_matrix(true_labels, predicted_labels).ravel()
#     229         # metrics['True Positive Rate'] = true_positive / (true_positive + false_negative)
#
# D:\Anaconda\lib\site-packages\sklearn\metrics\_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     570         labels = np.unique(y_true)
#     571         y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 572         return _average_binary_score(
#     573             partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     574             y_true,
#
# D:\Anaconda\lib\site-packages\sklearn\metrics\_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      73
#      74     if y_type == "binary":
# ---> 75         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      76
#      77     check_consistent_length(y_true, y_score, sample_weight)
#
# D:\Anaconda\lib\site-packages\sklearn\metrics\_ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     337     """Binary roc auc score."""
#     338     if len(np.unique(y_true)) != 2:
# --> 339         raise ValueError(
#     340             "Only one class present in y_true. ROC AUC score "
#     341             "is not defined in that case."
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-100f62972f2f> in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
accuracy_score([0, 0, 0], [0, 0, 1])
# Out:
# 0.6666666666666666

# %%
precision_score(filtered_gt['target'], sample)
# Out:
# 1.0

# %%
recall_score(filtered_gt['target'], sample)
# Out:
# 1.0

# %%
f1_score(filtered_gt['target'], sample)
# Out:
# 1.0
