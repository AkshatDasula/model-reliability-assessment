# %%
print("Hello World")
# Out:
# Hello World

# %%
pip show transformers
# Out:
# Name: transformers
# Version: 4.16.2
# Summary: State-of-the-art Natural Language Processing for TensorFlow 2.0 and PyTorch
# Home-page: https://github.com/huggingface/transformers
# Author: Thomas Wolf, Lysandre Debut, Victor Sanh, Julien Chaumond, Sam Shleifer, Patrick von Platen, Sylvain Gugger, Suraj Patil, Stas Bekman, Google AI Language Team Authors, Open AI team Authors, Facebook AI Authors, Carnegie Mellon University Authors
# Author-email: thomas@huggingface.co
# License: Apache
# Location: d:\anaconda\lib\site-packagesNote: you may need to restart the kernel to use updated packages.
# Requires: requests, packaging, filelock, sacremoses, pyyaml, huggingface-hub, tqdm, numpy, regex, tokenizers
# Required-by: simpletransformers, simplet5

# %%
import transformers

# %%
# Load model directly
from transformers import AutoModel
model = AutoModel.from_pretrained("clinicalnlplab/me-llama")
# Out:
# 404 Client Error: Entry Not Found for url: https://huggingface.co/clinicalnlplab/me-llama/resolve/main/config.json
# ---------------------------------------------------------------------------
# EntryNotFoundError                        Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\transformers\configuration_utils.py in _get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     584             # Load from URL or cache if already cached
# --> 585             resolved_config_file = cached_path(
#     586                 config_file,
#
# D:\Anaconda\lib\site-packages\transformers\file_utils.py in cached_path(url_or_filename, cache_dir, force_download, proxies, resume_download, user_agent, extract_compressed_file, force_extract, use_auth_token, local_files_only)
#    1845         # URL, so get it from the cache (downloading if necessary)
# -> 1846         output_path = get_from_cache(
#    1847             url_or_filename,
#
# ...

# %%
# Install vLLM from pip:
# !pip install vllm
# Out:
# ...
#     ERROR: Command errored out with exit status 1:
#      command: 'D:\Anaconda\python.exe' 'D:\Anaconda\lib\site-packages\pip\_vendor\pep517\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\AKSHAT~1\AppData\Local\Temp\tmp19jcjce2'
#          cwd: C:\Users\Akshat Mittu\AppData\Local\Temp\pip-install-848f_sew\tokenizers_c5a5a0f3cfa34bb6b59904a609bc1ea1
#     Complete output (6 lines):
#
#     Cargo, the Rust package manager, is not installed or is not on PATH.
#     This package requires Rust and Cargo to compile extensions. Install it through
#     the system's package manager or via https://rustup.rs/
#
#     Checking for Rust toolchain....
#     ----------------------------------------
# ...

# %%
pip show vllm
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: vllm
